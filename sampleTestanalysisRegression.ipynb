# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sklearn.neural_network as sknn
import seaborn as sns

# %%
#df = pd.read_csv('Covid19IrelandWeek.csv',index_col='Week')
df = pd.read_csv('https://raw.githubusercontent.com/ianmcloughlin/2020A-machstat-project/master/dataset/powerproduction.csv')

# %%
df.shape
# Out:
# (500, 2)

# %%
df.isnull().sum()
# Out:
# speed    0
# power    0
# dtype: int64

# %%
sns.distplot(df)
# Out:
# C:\Users\G00387859\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df['power'],df['speed'])

# %%
#split the data
df2 = pd.read_csv('powerproduction1_2.csv')
df1 = pd.read_csv('powerproduction1.csv')
df = pd.read_csv('Fundamentals-of-Data-Analysis-Project-2020/powerproduction.csv')

# %% [markdown]
# ### simple regressioin analysis can only be accomplished when the data is normallized

# %% [markdown]
# splitting the data

# %%
sns.distplot(df)
# Out:
# C:\Users\G00387859\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(df1)
# Out:
# C:\Users\G00387859\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(df2)
# Out:
# C:\Users\G00387859\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df1['speed'],df1['power'])

# %% [markdown]
# #### Data processing

# %%
X=df1[['speed']].values
y=df1[['power']].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
linear_reg=LinearRegression()

# %% [markdown]
# Training the model

# %%
linear_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Y intercept ', linear_reg.intercept_)
print('Coefficient bi ',linear_reg.coef_)
# Out:
# Y intercept  [-7.93155693]
# Coefficient bi  [[3.21194478]]

# %%
y_pred=linear_reg.predict(X_test)

# %%
plt.scatter(X_train,y_train)
plt.plot(X_test,y_pred,color='red')

# %% [markdown]
# ### Data preprocessing
